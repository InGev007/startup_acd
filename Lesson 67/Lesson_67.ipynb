# %% [markdown]
# <a href="https://colab.research.google.com/github/InGev007/startup_acd/blob/main/Lesson%2067/Lesson_67.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Генеруємо данні
x = np.linspace(0, 50, 50)
y = np.linspace(0, 50, 50)
x += np.random.uniform(-4, 4, 50)
y += np.random.uniform(-4, 4, 50)

# %%
# Будуємо графік
plt.scatter(x, y)
plt.show()

# %%
# Створюємо модель нейронної мережі
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer=tf.keras.optimizers.Adam(1e-1), loss='mse')

# %%
# Проводими навчання
history = model.fit(x, y, epochs=200)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 1s 27ms/step - loss: 235.9865
# Epoch 2/200
# 2/2 [==============================] - 0s 16ms/step - loss: 92.4530
# Epoch 3/200
# 2/2 [==============================] - 0s 8ms/step - loss: 22.4178
# Epoch 4/200
# 2/2 [==============================] - 0s 7ms/step - loss: 9.6642
# Epoch 5/200
# 2/2 [==============================] - 0s 17ms/step - loss: 31.0308
# Epoch 6/200
# 2/2 [==============================] - 0s 14ms/step - loss: 47.0419
# Epoch 7/200
# 2/2 [==============================] - 0s 12ms/step - loss: 47.3169
# Epoch 8/200
# 2/2 [==============================] - 0s 12ms/step - loss: 33.8159
# Epoch 9/200
# 2/2 [==============================] - 0s 8ms/step - loss: 19.8224
# Epoch 10/200
# 2/2 [==============================] - 0s 9ms/step - loss: 10.4048
# Epoch 11/200
# 2/2 [==============================] - 0s 18ms/step - loss: 8.7753
# Epoch 12/200
# ...

# %%
# Робимо прогноз
y_pred = model.predict(x)
# Виводимо графік
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.show()
# Out:
# 2/2 [==============================] - 0s 6ms/step
