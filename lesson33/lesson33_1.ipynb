# %% [markdown]
# 1. Створіть xls-документ, що містить дані про марки автомобілів, їхню вартість, споживання палива, максимальну швидкість та вантажопідйомність. Кількість записів у документі – 20.

# %%
import pandas as pd

# Створення таблиці з даними
data = {
    'Марка автомобіля': ['Toyota', 'Honda', 'BMW', 'Mercedes', 'Ford', 'Nissan', 'Audi', 'Chevrolet', 'Kia', 'Hyundai', 'Lexus', 'Mazda', 'Peugeot', 'Renault', 'Subaru', 'Suzuki', 'Volkswagen', 'Volvo', 'Opel', 'Fiat'],
    'Вартість, тис. дол.': [30, 25, 50, 60, 20, 27, 55, 18, 22, 23, 40, 28, 32, 24, 35, 19, 33, 45, 21, 26],
    'Споживання палива, л/100 км': [6.5, 7.0, 8.5, 9.0, 7.5, 8.0, 8.2, 7.2, 6.8, 7.5, 7.0, 6.8, 6.9, 7.5, 8.0, 6.5, 7.0, 8.5, 7.2, 6.0],
    'Максимальна швидкість, км/год': [200, 190, 240, 250, 180, 200, 220, 170, 180, 190, 220, 200, 190, 180, 210, 190, 200, 230, 170, 160],
    'Вантажопідйомність, т': [1.5, 1.3, 1.8, 1.9, 1.2, 1.4, 1.7, 1.1, 1.2, 1.3, 1.8, 1.4, 1.3, 1.5, 1.6, 1.3, 1.4, 1.7, 1.2, 1.1]
}

df = pd.DataFrame(data)

# експорт DataFrame до Excel
df.to_excel('автомобілі.xls', index=False)
df
# Out:
# C:\Users\ingev\AppData\Local\Temp\ipykernel_5736\2217030582.py:15: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel('автомобілі.xls', index=False)
#    Марка автомобіля  Вартість, тис. дол.  Споживання палива, л/100 км  \
# 0            Toyota                   30                          6.5
# 1             Honda                   25                          7.0
# 2               BMW                   50                          8.5
# 3          Mercedes                   60                          9.0
# 4              Ford                   20                          7.5
# ...
